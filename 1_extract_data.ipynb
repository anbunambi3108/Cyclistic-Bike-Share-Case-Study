# %%
import os
import zipfile
from io import BytesIO
import requests
import xml.etree.ElementTree as ET

# %%
# URL of the Divvy Tripdata index
BUCKET_ROOT = "https://divvy-tripdata.s3.amazonaws.com"

# Folder where extracted files will be saved
TARGET_DIR = r"C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/"
LIST_URL = BUCKET_ROOT + "?list-type=2&max-keys=1000"

# %%
os.makedirs(TARGET_DIR, exist_ok=True)

# Robust session with retries
from requests.adapters import HTTPAdapter, Retry
session = requests.Session()
retries = Retry(
    total=5,
    connect=5,
    read=5,
    backoff_factor=0.5,
    status_forcelist=(429, 500, 502, 503, 504),
)
session.mount("https://", HTTPAdapter(max_retries=retries))
session.headers.update({"User-Agent": "divvy-downloader/1.0"})

def list_all_zip_keys():
    """List all object keys in the public S3 bucket that end with .zip (handles pagination)."""
    keys = []
    next_token = None

    while True:
        url = LIST_URL if not next_token else f"{LIST_URL}&continuation-token={next_token}"
        r = session.get(url, timeout=60)
        r.raise_for_status()

        root = ET.fromstring(r.content)
        # XML uses default namespace; handle it safely
        ns = {"s3": root.tag.split("}")[0].strip("{")} if "}" in root.tag else {}

        for key_el in root.findall("s3:Contents/s3:Key", ns) or root.findall("Contents/Key"):
            key = key_el.text.strip()
            if key.lower().endswith(".zip"):
                keys.append(key)

        is_truncated_el = root.find("s3:IsTruncated", ns) or root.find("IsTruncated")
        truncated = (is_truncated_el is not None and is_truncated_el.text.lower() == "true")

        if truncated:
            next_el = root.find("s3:NextContinuationToken", ns) or root.find("NextContinuationToken")
            next_token = next_el.text
        else:
            break

    return keys

def download_and_extract(key):
    url = f"{BUCKET_ROOT}/{key}"
    fname = os.path.basename(key)
    print(f"Downloading {fname} ...")
    resp = session.get(url, timeout=300)
    resp.raise_for_status()

    with zipfile.ZipFile(BytesIO(resp.content)) as zf:
        print(f"  Extracting {fname} -> {TARGET_DIR}")
        # Overwrite existing files to keep things simple; comment next line to prevent overwrites
        zf.extractall(TARGET_DIR)

def main():
    print("Listing files from S3 bucket...")
    zip_keys = list_all_zip_keys()
    print(f"Found {len(zip_keys)} zip files.\n")

    for i, key in enumerate(zip_keys, start=1):
        try:
            print(f"[{i}/{len(zip_keys)}]")
            download_and_extract(key)
        except Exception as e:
            print(f"❌ Problem with {key}: {e}")

    print("\n✅ Done! All archives downloaded and extracted to:")
    print(TARGET_DIR)

if __name__ == "__main__":
    main()
# Out:
# Listing files from S3 bucket...
# Found 84 zip files.
#
# [1/84]
# Downloading 202004-divvy-tripdata.zip ...
#   Extracting 202004-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [2/84]
# Downloading 202005-divvy-tripdata.zip ...
#   Extracting 202005-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [3/84]
# Downloading 202006-divvy-tripdata.zip ...
#   Extracting 202006-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [4/84]
# Downloading 202007-divvy-tripdata.zip ...
#   Extracting 202007-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [5/84]
# Downloading 202008-divvy-tripdata.zip ...
#   Extracting 202008-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [6/84]
# Downloading 202009-divvy-tripdata.zip ...
#   Extracting 202009-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [7/84]
# Downloading 202010-divvy-tripdata.zip ...
#   Extracting 202010-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [8/84]
# Downloading 202011-divvy-tripdata.zip ...
#   Extracting 202011-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [9/84]
# Downloading 202012-divvy-tripdata.zip ...
#   Extracting 202012-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [10/84]
# Downloading 202101-divvy-tripdata.zip ...
#   Extracting 202101-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [11/84]
# Downloading 202102-divvy-tripdata.zip ...
#   Extracting 202102-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [12/84]
# Downloading 202103-divvy-tripdata.zip ...
#   Extracting 202103-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [13/84]
# Downloading 202104-divvy-tripdata.zip ...
#   Extracting 202104-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [14/84]
# Downloading 202105-divvy-tripdata.zip ...
#   Extracting 202105-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [15/84]
# Downloading 202106-divvy-tripdata.zip ...
#   Extracting 202106-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [16/84]
# Downloading 202107-divvy-tripdata.zip ...
#   Extracting 202107-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [17/84]
# Downloading 202108-divvy-tripdata.zip ...
#   Extracting 202108-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [18/84]
# Downloading 202109-divvy-tripdata.zip ...
#   Extracting 202109-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [19/84]
# Downloading 202110-divvy-tripdata.zip ...
#   Extracting 202110-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [20/84]
# Downloading 202111-divvy-tripdata.zip ...
#   Extracting 202111-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [21/84]
# Downloading 202112-divvy-tripdata.zip ...
#   Extracting 202112-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [22/84]
# Downloading 202201-divvy-tripdata.zip ...
#   Extracting 202201-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [23/84]
# Downloading 202202-divvy-tripdata.zip ...
#   Extracting 202202-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [24/84]
# Downloading 202203-divvy-tripdata.zip ...
#   Extracting 202203-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [25/84]
# Downloading 202204-divvy-tripdata.zip ...
#   Extracting 202204-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [26/84]
# Downloading 202205-divvy-tripdata.zip ...
#   Extracting 202205-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [27/84]
# Downloading 202206-divvy-tripdata.zip ...
#   Extracting 202206-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [28/84]
# Downloading 202207-divvy-tripdata.zip ...
#   Extracting 202207-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [29/84]
# Downloading 202208-divvy-tripdata.zip ...
#   Extracting 202208-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [30/84]
# Downloading 202209-divvy-tripdata.zip ...
#   Extracting 202209-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [31/84]
# Downloading 202210-divvy-tripdata.zip ...
#   Extracting 202210-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [32/84]
# Downloading 202211-divvy-tripdata.zip ...
#   Extracting 202211-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [33/84]
# Downloading 202212-divvy-tripdata.zip ...
#   Extracting 202212-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [34/84]
# Downloading 202301-divvy-tripdata.zip ...
#   Extracting 202301-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [35/84]
# Downloading 202302-divvy-tripdata.zip ...
#   Extracting 202302-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [36/84]
# Downloading 202303-divvy-tripdata.zip ...
#   Extracting 202303-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [37/84]
# Downloading 202304-divvy-tripdata.zip ...
#   Extracting 202304-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [38/84]
# Downloading 202305-divvy-tripdata.zip ...
#   Extracting 202305-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [39/84]
# Downloading 202306-divvy-tripdata.zip ...
#   Extracting 202306-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [40/84]
# Downloading 202307-divvy-tripdata.zip ...
#   Extracting 202307-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [41/84]
# Downloading 202308-divvy-tripdata.zip ...
#   Extracting 202308-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [42/84]
# Downloading 202309-divvy-tripdata.zip ...
#   Extracting 202309-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [43/84]
# Downloading 202310-divvy-tripdata.zip ...
#   Extracting 202310-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [44/84]
# Downloading 202311-divvy-tripdata.zip ...
#   Extracting 202311-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [45/84]
# Downloading 202312-divvy-tripdata.zip ...
#   Extracting 202312-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [46/84]
# Downloading 202401-divvy-tripdata.zip ...
#   Extracting 202401-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [47/84]
# Downloading 202402-divvy-tripdata.zip ...
#   Extracting 202402-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [48/84]
# Downloading 202403-divvy-tripdata.zip ...
#   Extracting 202403-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [49/84]
# Downloading 202404-divvy-tripdata.zip ...
#   Extracting 202404-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [50/84]
# Downloading 202405-divvy-tripdata.zip ...
#   Extracting 202405-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [51/84]
# Downloading 202406-divvy-tripdata.zip ...
#   Extracting 202406-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [52/84]
# Downloading 202407-divvy-tripdata.zip ...
#   Extracting 202407-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [53/84]
# Downloading 202408-divvy-tripdata.zip ...
#   Extracting 202408-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [54/84]
# Downloading 202409-divvy-tripdata.zip ...
#   Extracting 202409-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [55/84]
# Downloading 202410-divvy-tripdata.zip ...
#   Extracting 202410-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [56/84]
# Downloading 202411-divvy-tripdata.zip ...
#   Extracting 202411-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [57/84]
# Downloading 202412-divvy-tripdata.zip ...
#   Extracting 202412-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [58/84]
# Downloading 202501-divvy-tripdata.zip ...
#   Extracting 202501-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [59/84]
# Downloading 202502-divvy-tripdata.zip ...
#   Extracting 202502-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [60/84]
# Downloading 202503-divvy-tripdata.zip ...
#   Extracting 202503-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [61/84]
# Downloading 202504-divvy-tripdata.zip ...
#   Extracting 202504-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [62/84]
# Downloading 202505-divvy-tripdata.zip ...
#   Extracting 202505-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [63/84]
# Downloading 202506-divvy-tripdata.zip ...
#   Extracting 202506-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [64/84]
# Downloading 202507-divvy-tripdata.zip ...
#   Extracting 202507-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [65/84]
# Downloading 202508-divvy-tripdata.zip ...
#   Extracting 202508-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [66/84]
# Downloading 202509-divvy-tripdata.zip ...
#   Extracting 202509-divvy-tripdata.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [67/84]
# Downloading Divvy_Stations_Trips_2013.zip ...
#   Extracting Divvy_Stations_Trips_2013.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [68/84]
# Downloading Divvy_Stations_Trips_2014_Q1Q2.zip ...
#   Extracting Divvy_Stations_Trips_2014_Q1Q2.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [69/84]
# Downloading Divvy_Stations_Trips_2014_Q3Q4.zip ...
#   Extracting Divvy_Stations_Trips_2014_Q3Q4.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [70/84]
# Downloading Divvy_Trips_2015-Q1Q2.zip ...
#   Extracting Divvy_Trips_2015-Q1Q2.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [71/84]
# Downloading Divvy_Trips_2015_Q3Q4.zip ...
#   Extracting Divvy_Trips_2015_Q3Q4.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [72/84]
# Downloading Divvy_Trips_2016_Q1Q2.zip ...
#   Extracting Divvy_Trips_2016_Q1Q2.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [73/84]
# Downloading Divvy_Trips_2016_Q3Q4.zip ...
#   Extracting Divvy_Trips_2016_Q3Q4.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [74/84]
# Downloading Divvy_Trips_2017_Q1Q2.zip ...
#   Extracting Divvy_Trips_2017_Q1Q2.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [75/84]
# Downloading Divvy_Trips_2017_Q3Q4.zip ...
#   Extracting Divvy_Trips_2017_Q3Q4.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [76/84]
# Downloading Divvy_Trips_2018_Q1.zip ...
#   Extracting Divvy_Trips_2018_Q1.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [77/84]
# Downloading Divvy_Trips_2018_Q2.zip ...
#   Extracting Divvy_Trips_2018_Q2.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [78/84]
# Downloading Divvy_Trips_2018_Q3.zip ...
#   Extracting Divvy_Trips_2018_Q3.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [79/84]
# Downloading Divvy_Trips_2018_Q4.zip ...
#   Extracting Divvy_Trips_2018_Q4.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [80/84]
# Downloading Divvy_Trips_2019_Q1.zip ...
#   Extracting Divvy_Trips_2019_Q1.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [81/84]
# Downloading Divvy_Trips_2019_Q2.zip ...
#   Extracting Divvy_Trips_2019_Q2.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [82/84]
# Downloading Divvy_Trips_2019_Q3.zip ...
#   Extracting Divvy_Trips_2019_Q3.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [83/84]
# Downloading Divvy_Trips_2019_Q4.zip ...
#   Extracting Divvy_Trips_2019_Q4.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
# [84/84]
# Downloading Divvy_Trips_2020_Q1.zip ...
#   Extracting Divvy_Trips_2020_Q1.zip -> C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
#
# ✅ Done! All archives downloaded and extracted to:
# C:/Users/anbun/Desktop/Portfolio projects/Google Data Analytics Capstone/Data/
